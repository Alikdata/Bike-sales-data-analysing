# %%
import pandas as pd

# %%
# bike sales data exploring using pandas library

# %%
bike_df=pd.read_excel(r'C:\Users\user\Downloads\projects.xlsx')

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
#looking at some pandas methods and fuctions

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108374 entries, 0 to 108373
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              62322 non-null  datetime64[ns]
#  1   Customer_Age      62322 non-null  float64
#  2   Customer_Gender   62322 non-null  object
#  3   Country           62322 non-null  object
#  4   State             62322 non-null  object
#  5   Product_Category  62322 non-null  object
#  6   Sub_Category      62322 non-null  object
#  7   Product           62322 non-null  object
#  8   Order_Quantity    62322 non-null  float64
#  9   Unit_Cost         62322 non-null  float64
#  10  Unit_Price        62322 non-null  float64
#  11  Profit            62322 non-null  float64
#  12  Cost              62322 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 10.7+ MB

# %%
bike_df.describe()
# Out:
#        Customer_Age  Order_Quantity     Unit_Cost    Unit_Price        Profit  \
# count  62322.000000    62322.000000  62322.000000  62322.000000  62322.000000
# mean      35.989089       15.079811      5.070088     12.822149     89.205401
# std       11.384345        8.726795      7.386322     19.844873    137.577824
# min       17.000000        1.000000      1.000000      2.000000     -5.000000
# 25%       27.000000        7.000000      2.000000      5.000000     15.000000
# 50%       35.000000       15.000000      2.000000      5.000000     41.000000
# 75%       44.000000       23.000000      7.000000     10.000000     85.000000
# max       87.000000       32.000000     59.000000    159.000000   2214.000000
#
#                Cost
# count  62322.000000
# mean      70.041847
# std       94.995468
# min        1.000000
# 25%       16.000000
# 50%       34.000000
# 75%       80.000000
# max     1350.000000

# %%
bike_df.loc[15]
# Out:
# Date                2015-08-02 00:00:00
# Customer_Age                       29.0
# Customer_Gender                       M
# Country                          Canada
# State                  British Columbia
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                      7.0
# Unit_Cost                          45.0
# Unit_Price                        120.0
# Profit                            517.0
# Cost                              315.0
# Name: 15, dtype: object

# %%
bike_df['Customer_Age']
# Out:
# 0         19.0
# 1         19.0
# 2         49.0
# 3         49.0
# 4         47.0
#           ...
# 108369    37.0
# 108370    37.0
# 108371    37.0
# 108372    37.0
# 108373    37.0
# Name: Customer_Age, Length: 108374, dtype: float64

# %%
bike_df.at[15,'Customer_Age']
# Out:
# 29.0

# %%
bike_df.head(10)
# Out:
#         Date  Customer_Age Customer_Gender    Country             State  \
# 0 2013-11-26          19.0               M     Canada  British Columbia
# 1 2015-11-26          19.0               M     Canada  British Columbia
# 2 2014-03-23          49.0               M  Australia   New South Wales
# 3 2016-03-23          49.0               M  Australia   New South Wales
# 4 2014-05-15          47.0               F  Australia   New South Wales
# 5 2016-05-15          47.0               F  Australia   New South Wales
# 6 2014-05-22          47.0               F  Australia          Victoria
# 7 2016-05-22          47.0               F  Australia          Victoria
# 8 2014-02-22          35.0               M  Australia          Victoria
# 9 2016-02-22          35.0               M  Australia          Victoria
#
#   Product_Category Sub_Category              Product  Order_Quantity  \
# 0      Accessories   Bike Racks  Hitch Rack - 4-Bike             8.0
# ...

# %%
bike_df.tail(10)
# Out:
#              Date  Customer_Age Customer_Gender Country              State  \
# 108364 2016-06-07          37.0               M  France  Seine Saint Denis
# 108365 2016-06-07          37.0               M  France  Seine Saint Denis
# 108366 2014-03-04          37.0               F  France      Seine (Paris)
# 108367 2014-03-04          37.0               F  France      Seine (Paris)
# 108368 2016-03-04          37.0               F  France      Seine (Paris)
# 108369 2016-03-04          37.0               F  France      Seine (Paris)
# 108370 2014-04-27          37.0               F  France      Seine (Paris)
# 108371 2014-04-27          37.0               F  France      Seine (Paris)
# 108372 2016-04-27          37.0               F  France      Seine (Paris)
# 108373 2016-04-27          37.0               F  France      Seine (Paris)
#
#        Product_Category     Sub_Category              Product  Order_Quantity  \
# ...

# %%
bike_df.sample(10)
# Out:
#             Date  Customer_Age Customer_Gender         Country  \
# 21280 2014-02-22          38.0               M  United Kingdom
# 21433 2015-07-26          24.0               M       Australia
# 21311 2015-08-25          37.0               M       Australia
# 79731 2016-02-22          31.0               M       Australia
# 36192        NaT           NaN             NaN             NaN
# 76935 2016-01-10          38.0               M   United States
# 87750 2014-01-22          30.0               M       Australia
# 17788 2014-02-24          22.0               M   United States
# 71059        NaT           NaN             NaN             NaN
# 85975 2016-02-19          19.0               M  United Kingdom
#
#                  State Product_Category     Sub_Category  \
# 21280          England         Clothing             Caps
# 21433         Tasmania      Accessories         Cleaners
# 21311  New South Wales      Accessories         Cleaners
# ...

# %%
#adding new colums,sorting,groupping data

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
bike_df['Revenue']=bike_df.Profit+bike_df.Cost

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
highest_revenue=bike_df[bike_df.Revenue>2000]

# %%
highest_revenue.sort_values('Revenue',ascending=False).head(10)
# Out:
#           Date  Customer_Age Customer_Gender         Country  \
# 245 2016-01-07          31.0               M          Canada
# 182 2014-01-17          53.0               F   United States
# 90  2014-02-12          46.0               M   United States
# 244 2014-01-07          31.0               M          Canada
# 183 2016-01-17          53.0               F   United States
# 95  2015-09-23          41.0               F         Germany
# 327 2016-01-26          35.0               F  United Kingdom
# 339 2016-06-11          45.0               F          Canada
# 101 2016-05-11          32.0               M   United States
# 91  2016-02-12          46.0               M   United States
#
#                 State Product_Category Sub_Category              Product  \
# 245  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 182        California      Accessories   Bike Racks  Hitch Rack - 4-Bike
# ...

# %%
#1.groupping revenue for country

# %%
groupped_df=bike_df.groupby(['Country','Product_Category'])[['Cost','Profit','Revenue']].std()

# %%
groupped_df
# Out:
#                                       Cost      Profit     Revenue
# Country        Product_Category
# Australia      Accessories       96.824486  121.326447  217.776955
#                Clothing          61.332817    7.185086   66.501526
# Canada         Accessories       96.314711  161.033767  257.210853
#                Clothing          60.021845   16.344693   76.363832
# France         Accessories       93.152382  120.815583  213.277427
#                Clothing          55.830012   11.769708   62.837306
# Germany        Accessories       99.833369  141.446256  240.602457
#                Clothing          59.446707   13.015484   68.855578
# United Kingdom Accessories       92.712885  146.134866  238.670820
#                Clothing          61.582596   14.421098   76.001245
# United States  Accessories       97.497394  144.567611  240.846410
#                Clothing          60.817785   18.236404   73.139462

# %%
#2.groupping Reveneue for gender

# %%
Gender_revenue=bike_df.groupby(['Customer_Gender','Country'])[['Cost','Profit','Revenue']].sum()

# %%
Gender_revenue
# Out:
#                                     Cost     Profit    Revenue
# Customer_Gender Country
# F               Australia       424971.0   463156.0   888127.0
#                 Canada          256860.0   377179.0   634039.0
#                 France          201513.0   227261.0   428774.0
#                 Germany         211130.0   256445.0   467575.0
#                 United Kingdom  247940.0   348293.0   596233.0
#                 United States   719793.0   932492.0  1652285.0
# M               Australia       441850.0   491921.0   933771.0
#                 Canada          376603.0   583885.0   960488.0
#                 France          196198.0   216743.0   412941.0
#                 Germany         216696.0   269571.0   486267.0
#                 United Kingdom  227849.0   299322.0   527171.0
#                 United States   843745.0  1093191.0  1936936.0

# %%
#working with dates

# %%
bike_df['Date']=pd.to_datetime(bike_df.Date)

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
bike_df['year']=pd.DatetimeIndex(bike_df.Date).year

# %%
bike_df['month']=pd.DatetimeIndex(bike_df.Date).month

# %%
bike_df['day']=pd.DatetimeIndex(bike_df.Date).day

# %%
bike_df['weekday']=pd.DatetimeIndex(bike_df.Date).weekday

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...

# %%
#4 groupping revenue into years

# %%
years_revenue=bike_df.groupby(['year','Country'])[['Cost','Profit','Revenue']].sum()

# %%
years_revenue
# Out:
#                            Cost    Profit    Revenue
# year   Country
# 2013.0 Australia       195632.0  216675.0   412307.0
#        Canada          142511.0  218785.0   361296.0
#        France           90356.0  101943.0   192299.0
#        Germany          86749.0  107539.0   194288.0
#        United Kingdom  101940.0  138087.0   240027.0
#        United States   354221.0  461250.0   815471.0
# 2014.0 Australia       244540.0  268137.0   512677.0
#        Canada          178297.0  267992.0   446289.0
#        France          111936.0  123858.0   235794.0
#        Germany         130519.0  159579.0   290098.0
#        United Kingdom  140144.0  191406.0   331550.0
#        United States   440498.0  568989.0  1009487.0
# 2015.0 Australia       190205.0  210742.0   400947.0
#        Canada          139430.0  214098.0   353528.0
#        France           87415.0   98661.0   186076.0
#        Germany          83888.0  103839.0   187727.0
# ...

# %%
#finding Revenue only in may in 2016 for males in canada and comparising it with United States

# %%
may_2016_males_df=bike_df[bike_df.year==2016]

# %%
month_df=may_2016_males_df[may_2016_males_df.month==5]

# %%
 gender_df=month_df[month_df.Customer_Gender=='M']

# %%
canada_df=gender_df[gender_df.Country=='Canada']

# %%
united_states_df=gender_df[gender_df.Country=='United_states']

# %%
canada_df.groupby('day')['Revenue'].sum()
# Out:
# day
# 1.0      808.0
# 2.0      888.0
# 3.0     2709.0
# 4.0      278.0
# 5.0      523.0
# 6.0     1529.0
# 7.0      705.0
# 8.0      175.0
# 9.0     1286.0
# 10.0    1909.0
# 11.0    1726.0
# 12.0     339.0
# 13.0    3187.0
# 14.0    2768.0
# 15.0     942.0
# 16.0     713.0
# 17.0    1702.0
# 19.0    2026.0
# 20.0      22.0
# 21.0     243.0
# 22.0      68.0
# 23.0     629.0
# 24.0    4293.0
# 25.0    1115.0
# 26.0    2707.0
# 27.0     264.0
# 28.0    1857.0
# 29.0     757.0
# 30.0    1263.0
# 31.0    1338.0
# Name: Revenue, dtype: float64

# %%
bike_df
# Out:
#              Date  Customer_Age Customer_Gender    Country             State  \
# 0      2013-11-26          19.0               M     Canada  British Columbia
# 1      2015-11-26          19.0               M     Canada  British Columbia
# 2      2014-03-23          49.0               M  Australia   New South Wales
# 3      2016-03-23          49.0               M  Australia   New South Wales
# 4      2014-05-15          47.0               F  Australia   New South Wales
# ...           ...           ...             ...        ...               ...
# 108369 2016-03-04          37.0               F     France     Seine (Paris)
# 108370 2014-04-27          37.0               F     France     Seine (Paris)
# 108371 2014-04-27          37.0               F     France     Seine (Paris)
# 108372 2016-04-27          37.0               F     France     Seine (Paris)
# 108373 2016-04-27          37.0               F     France     Seine (Paris)
#
# ...
